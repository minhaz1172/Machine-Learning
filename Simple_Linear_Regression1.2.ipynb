# %% [markdown]
# # Salary Prediction by simple linear regression

# %%
# import necessary Liabraires
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # lOAD THE DATASET

# %%
df= pd.read_csv('C:\AI and ML\Machine Learning\Machine-Learning\Regression\Salary Data (1).csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x=df[['YearsExperience']]
y=df[['Salary']]

# %%
plt.scatter(x,y)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Years of Experience vs Salary')
# Out:
# Text(0.5, 1.0, 'Years of Experience vs Salary')

# %% [markdown]
# #  split the data into training and test

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
# fit the model
model.fit(X_train,y_train)
# make predictions
y_pred=model.predict(X_test)
y_pred
# Out:
# array([[115790.21011287],
#        [ 71498.27809463],
#        [102596.86866063],
#        [ 75267.80422384],
#        [ 55477.79204548],
#        [ 60189.69970699]])

# %%
# Evaluate the model
mse= mean_squared_error(y_test, y_pred)
r2= r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
coefficient=model.coef_
intercept=model.intercept_
print(f'Coefficient: {coefficient}')
print(f'Intercept: {intercept}')
# Out:
# Mean Squared Error: 49830096.85590839
# R^2 Score: 0.9024461774180497
# Coefficient: [[9423.81532303]]
# Intercept: [25321.58301178]

# %%
# Plot the predicted output Scatter plot
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.scatter(X_test, y_pred, color='red', label='Predicted')
plt.plot(X_test, model.predict(X_test), color='green', label='Rgeression Line') #Regression line
plt.xlabel('Years\ of Experience')
plt.ylabel('Salary')
plt.title('Actual vs Predicted Salary')
plt.legend()
plt.show()
